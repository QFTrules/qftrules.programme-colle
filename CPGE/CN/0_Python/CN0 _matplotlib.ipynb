# %% [markdown]
# # CN0 - Bibliothèque graphique Matplotlib
#
# Objectif : *« Réviser l'utilisation de la bibliothèque graphique matplotlib. »*
#
# Lien capytale : https://capytale2.ac-paris.fr/web/c/c697-1816631
#
# Lier corrigé : https://capytale2.ac-paris.fr/web/c/d830-3818298

# %% [raw]
# La bibliothèque matplotlib est une bibliothèque python qui permet de réaliser des graphique pour la physique. Elle s'importe souvent en conjonction avec la bibliothèque matplotlib.pyplot, avec les alias suivants :

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [raw]
# Pour définir un graphique, il faut d'abord appeler la méthode figure() :

# %%
plt.figure()

# %% [raw]
# Cette fonction figure peut prendre des arguments optionnels, mais nous n'étudierons pas cette possibilité.

# %% [raw]
# Cette bibliothèque est particulièrement adapté à la représentation graphique de listes ou tableaux numpy. Par exemple, définissons un tableau x contenant des abscisses, et un tableau y contenant des ordonnées.

# %%
import numpy as np
x = np.linspace(0, 2, 100)
y = x**2

# %% [raw]
# On peut représenter les points (x,y) sur la figure avec la méthode plot().

# %%
plt.plot(x, y, label='x^2')

# %% [raw]
# 1) Faire de même pour représenter la fonction exp(x).

# %%
...
# Out:
# Ellipsis

# %% [raw]
# Pour afficher la figure, on utilise toujours comme dernière commande la ligne suivante :

# %%
plt.show()

# %% [raw]
# 2) Redéfinir une nouvelle figure sur laquelle vous afficherez un graphe similaire à celui du dessus mais pour la fonction exp(x).

# %% [raw]
# On peut également ajouter des étiquettes sur les axes des abscisses ou des ordonnées, avec les commandes suivantes :

# %%
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(64.21115451388889, 0.5, 'y')

# %% [raw]
# 3) Reprendre la question 2 en annotant les axes avec les étiquettes « abscisse » et « ordonnée ».

# %% [raw]
# Enfin, on peut ajouter un titre et une légende avec les commandes suivantes.

# %%
plt.title("Titre")
plt.legend()

# %% [raw]
# 4) Reprendre la question 3 en donnant le titre « Exponentielle » et en légendant la figure.
