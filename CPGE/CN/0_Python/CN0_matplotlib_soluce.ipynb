# %% [markdown]
# # Bibliothèque graphique Matplotlib

# %% [raw]
# # La bibliothèque matplotlib est une bibliothèque python qui permet de réaliser des graphiques pour la physique. Elle s'importe souvent en conjonction avec la bibliothèque matplotlib.pyplot, avec les alias suivants :

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [raw]
# Pour définir un graphique, il faut d'abord appeler la méthode figure() :

# %%
plt.figure()

# %% [raw]
# Cette fonction figure peut prendre des arguments optionnels, mais nous n'étudierons pas cette possibilité.

# %% [raw]
# Cette bibliothèque est particulièrement adapté à la représentation graphique de listes ou tableaux numpy. Par exemple, définissons un tableau x contenant des abscisses, et un tableau y contenant des ordonnées.

# %%
import numpy as np
x = np.linspace(0, 2, 100)
y = x**2

# %% [raw]
# On peut représenter les points (x,y) sur la figure avec la méthode plot().

# %%
plt.plot(x, y, label='x^2')

# %%
Pour afficher la figure, on utilise toujours comme dernière commande la ligne suivante :

# %%
plt.show()

# %% [raw]
# 1) Créer une nouvelle figure qui représente le graphe de la fonction exp(x).

# %%
plt.figure()
z = np.exp(x)
plt.plot(x, z, label='exp(x)')
plt.show()

# %% [raw]
# On peut également ajouter des étiquettes sur les axes des abscisses ou des ordonnées, en ajoutant les commandes suivantes avant la commande plt.show() :

# %%
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(100.92838541666666, 0.5, 'y')

# %% [raw]
# 2) Reprendre la question 1 en annotant les axes avec les étiquettes « abscisse » et « ordonnée ».

# %%
plt.figure()
z = np.exp(x)
plt.plot(x, z, label='exp(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [raw]
# Enfin, on peut ajouter un titre et une légende en ajoutant les commandes suivantes avant la commande plt.show().

# %%
plt.title("Titre")
plt.legend()

# %% [raw]
# 4) Reprendre la question 3 en donnant le titre « Exponentielle » et en légendant la figure.

# %%
plt.figure()
z = np.exp(x)
plt.plot(x, z, label='exp(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title("Exponentielle")
plt.legend()
plt.show()
